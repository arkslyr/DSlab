# %%
from matplotlib import pyplot as plt

# %%
x=[5,7,8,7,2,17,2,9,4,11,19,9,6]
y=[99,86,87,88,100,86,103,87,94,78,77,85,86]
x2=[1,4,5,7,7,4,3,5,4,6,2,7,3,6,2,6]
y2=[23,23,76,54,76,46,76,53,47,65,31,45,21,78,54,34]
plt.scatter(x,y,color='cyan',marker='^')
plt.scatter(x2,y2,color='red',marker='o')
plt.title('Scatter plot')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()
