# %% [markdown]
# actual(y)   pred(f)    Error E=y-f    E1^2    E2=y-Mean    E2^2
# 10          10          0               0       -10         100
# 20          20          0               0       0           0
# 30          30          0               0       10          100
# Mean=20                                 Sum=0(SSres)       sum=200(SStotal)
#
# Sum of squares of Residual Error(E1^2)
#
# R^2=1-(SSres/SStotal)
#
# R^2=1-(0/200)=1
#
# ------------------------------------------------------------------------------
#
# actual(y)   pred(f)    Error E=y-f    E1^2    E2=y-Mean    E2^2
# 10          20          -10             100       -10         100
# 20          20          0               0           0           0
# 30          20          10              100        10         100
# Mean=20                            Sum=200(SSres)         sum=200(SStotal)
#
# Sum of squares of Residual Error(E1^2)
#
# R^2=1-(SSres/SStotal)
#
# R^2=1-(200/200)=0
#
# ------------------------------------------------------------------------------
#
# actual(y)   pred(f)    Error E=y-f    E1^2    E2=y-Mean    E2^2
# 10          30          -20             400       -10         100
# 20          10          10              100         0           0
# 30          20          10              100        10         100
# Mean=20                            Sum=600(SSres)         sum=200(SStotal)
#
# Sum of squares of Residual Error(E1^2)
#
# R^2=1-(SSres/SStotal)
#
# R^2=1-(600/200)=1-3=-2
#
# ------------------------------------------------------------------------------

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
import random

# %%
np.random.seed(42)
X=2*np.random.rand(100,1)
y=4+(3*x)+np.random.rand(100,1)
print(X,y)
# Out:
# [[0.74908024]
#  [1.90142861]
#  [1.46398788]
#  [1.19731697]
#  [0.31203728]
#  [0.31198904]
#  [0.11616722]
#  [1.73235229]
#  [1.20223002]
#  [1.41614516]
#  [0.04116899]
#  [1.9398197 ]
#  [1.66488528]
#  [0.42467822]
#  [0.36364993]
#  [0.36680902]
#  [0.60848449]
#  [1.04951286]
#  [0.86389004]
#  [0.58245828]
#  [1.22370579]
#  [0.27898772]
#  [0.5842893 ]
#  [0.73272369]
#  [0.91213997]
#  [1.57035192]
#  [0.39934756]
#  [1.02846888]
#  [1.18482914]
#  [0.09290083]
#  [1.2150897 ]
#  [0.34104825]
#  [0.13010319]
#  [1.89777107]
#  [1.93126407]
#  [1.6167947 ]
#  [0.60922754]
#  [0.19534423]
#  [1.36846605]
#  [0.88030499]
#  [0.24407647]
#  [0.99035382]
#  [0.06877704]
#  [1.8186408 ]
#  [0.51755996]
#  [1.32504457]
#  [0.62342215]
#  [1.04013604]
#  [1.09342056]
#  [0.36970891]
#  [1.93916926]
#  [1.55026565]
#  [1.87899788]
#  [1.7896547 ]
#  [1.19579996]
#  [1.84374847]
#  [0.176985  ]
#  [0.39196572]
#  [0.09045458]
#  [0.65066066]
#  [0.77735458]
#  [0.54269806]
# ...

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2,random_state=42)

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
mse=mean_squared_error(y_test,y_pred)
print("Mean Squared Error :",mse)
# Out:
# Mean Squared Error : 0.0954430346975895

# %%
r2=r2_score(y_test,y_pred)
print("R2 Score: ",r2)
# Out:
# R2 Score:  0.9742947589810751

# %%
plt.scatter(X,y,color='red',marker='o',label='Actual Data')
plt.plot(X_test,y_pred,color='blue',label='Predicted')
plt.title('Actual  vs Predicted')
plt.legend()
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
n=float(input('Enter a value to predict :'))
n_reshaped=np.array([[n]])
n_predict=model.predict(n_reshaped)
print('Predicted value is :',n_predict)
# Out:
# Predicted value is : [[21.46491261]]

# %%
n
